# %% [markdown]
# # Phase 1: Data Preparation and Preprocessing

# %% [markdown]
# ## Dataset Collection and Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/PCOS_data_simple.csv')
print(df.shape)
display(df.head())
# Out:
# (541, 45)
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.3           15                78                22  ...
# 1  24.9           15                74                20  ...
# 2  25.3           11                72                18  ...
# 3  29.7           13                72                20  ...
# 4  20.1           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
df.columns
# Out:
# Index(['Sl. No', 'Patient File No.', 'PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ',
#        'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of abortions',
#        '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)',
#        'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio',
#        'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)',
#        'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)',
#        'Unnamed: 44'],
#       dtype='object')

# %%
print(len(df))
# Out:
# 541

# %%
# deleting uninformative cols
df.drop(columns=['Sl. No', 'Patient File No.', 'Unnamed: 44'],inplace=True)
df.head(2)
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  \
# 0           0          28         44.6        152.0  19.3           15
# 1           0          36         65.0        161.5  24.9           15
#
#    Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  ...  \
# 0                78                22     10.48           2  ...
# 1                74                20     11.70           2  ...
#
#    Pimples(Y/N)  Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0             0              1.0                  0                  110
# 1             0              0.0                  0                  120
#
#    BP _Diastolic (mmHg) Follicle No. (L)  Follicle No. (R)  \
# 0                    80                3                 3
# 1                    70                3                 5
#
#    Avg. F size (L) (mm)  Avg. F size (R) (mm)  Endometrium (mm)
# 0                  18.0                  18.0               8.5
# ...

# %%
# missing values
df.isna().sum()  # no missing values
# Out:
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# BMI                       0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Marraige Status (Yrs)     1
# Pregnant(Y/N)             0
# No. of abortions          0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# FSH/LH                    0
# Hip(inch)                 0
# Waist(inch)               0
# Waist:Hip Ratio           0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# Hair loss(Y/N)            0
# Pimples(Y/N)              0
# ...

# %%
# prompt: make a bar plot of missing values in df

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the percentage of missing values for each column
missing_percentages = df.isna().sum() / len(df) * 100

# Create the bar plot
plt.figure(figsize=(14, 8))
sns.barplot(x=missing_percentages.index, y=missing_percentages.values)
plt.xticks(rotation=90)
plt.xlabel('Columns')
plt.ylabel('Percentage of Missing Values')
plt.title('Missing Values in PCOS Dataset')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Height(Cm) ', 'BMI',
#        'Blood Group', 'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)',
#        'Pregnant(Y/N)', 'No. of abortions', '  I   beta-HCG(mIU/mL)',
#        'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH',
#        'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)',
#        'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)',
#        'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
# prompt: apply kNN imputation to fill the null values of the column Marriage Status (Yrs), and Fast food (Y/N)

import pandas as pd
from sklearn.impute import KNNImputer

# Assuming df is your DataFrame and it has columns 'Marriage Status (Yrs)' and 'Fast food (Y/N)'
# with missing values.

# Select the columns with missing values that you want to impute
columns_to_impute = ['Marraige Status (Yrs)', 'Fast food (Y/N)']
df_to_impute = df[columns_to_impute].copy()

# Create a KNN imputer
imputer = KNNImputer(n_neighbors=5)  # You can adjust the number of neighbors

# Fit and transform the imputer on your selected columns
df_imputed = pd.DataFrame(imputer.fit_transform(df_to_impute), columns=columns_to_impute)

# Replace the original columns with the imputed values in your main DataFrame
df[columns_to_impute] = df_imputed

# Now, df should have the missing values in 'Marriage Status (Yrs)' and 'Fast food (Y/N)' filled using kNN imputation.

# %%
# Replacing '.' with empty string in the 'II    beta-HCG(mIU/mL)' column
df['II    beta-HCG(mIU/mL)'] = df['II    beta-HCG(mIU/mL)'].str.replace('.', '', regex=False).astype(float)
# Replacing any non-digit characters with empty string before converting to float
df['AMH(ng/mL)'] = pd.to_numeric(df['AMH(ng/mL)'].str.replace('[^0-9.]', '', regex=True), errors='coerce')
df['AMH(ng/mL)'] = df['AMH(ng/mL)'].fillna(df['AMH(ng/mL)'].median())
df.dtypes
# Out:
# PCOS (Y/N)                  int64
#  Age (yrs)                  int64
# Weight (Kg)               float64
# Height(Cm)                float64
# BMI                       float64
# Blood Group                 int64
# Pulse rate(bpm)             int64
# RR (breaths/min)            int64
# Hb(g/dl)                  float64
# Cycle(R/I)                  int64
# Cycle length(days)          int64
# Marraige Status (Yrs)     float64
# Pregnant(Y/N)               int64
# No. of abortions            int64
#   I   beta-HCG(mIU/mL)    float64
# II    beta-HCG(mIU/mL)    float64
# FSH(mIU/mL)               float64
# LH(mIU/mL)                float64
# FSH/LH                    float64
# Hip(inch)                   int64
# Waist(inch)                 int64
# Waist:Hip Ratio           float64
# TSH (mIU/L)               float64
# AMH(ng/mL)                float64
# PRL(ng/mL)                float64
# Vit D3 (ng/mL)            float64
# PRG(ng/mL)                float64
# ...

# %%
# prompt: create a beautiful KDE histogram of AMH(ng/mL)

import seaborn as sns

sns.kdeplot(data=df, x='AMH(ng/mL)',fill=True)
plt.xlabel('AMH(ng/mL)')
plt.ylabel('Density')
plt.title('Distribution of AMH(ng/mL)Skewness: 3.28')
plt.show()

# %%
# prompt: calculate skewness of AMH(ng/mL)

from scipy.stats import skew

# Calculate the skewness of 'AMH(ng/mL)'
skewness_amh = skew(df['AMH(ng/mL)'])

print(f"Skewness of AMH(ng/mL): {skewness_amh}")
# Out:
# Skewness of AMH(ng/mL): 3.287865484398488

# %%
# Manual feature engineering
df['avg_sys_dia'] = (df['BP _Systolic (mmHg)'] + df['BP _Diastolic (mmHg)']) / 2
df['avg_num_folicol'] = (df['Follicle No. (L)'] + df['Follicle No. (R)']) / 2
df['avg_size_folicol'] = (df['Avg. F size (L) (mm)'] + df['Avg. F size (R) (mm)']) / 2


df.drop(columns=['Weight (Kg)', 'Height(Cm) ', 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Hip(inch)', 'Waist(inch)', 'Follicle No. (L)'
,'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)'],inplace=True)

df.shape
# Out:
# (541, 35)

# %%
df.head(3)
# Out:
#    PCOS (Y/N)   Age (yrs)   BMI  Blood Group  Pulse rate(bpm)   \
# 0           0          28  19.3           15                78
# 1           0          36  24.9           15                74
# 2           1          33  25.3           11                72
#
#    RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  Cycle length(days)  \
# 0                22     10.48           2                   5
# 1                20     11.70           2                   5
# 2                18     11.80           2                   5
#
#    Marraige Status (Yrs)  ...  hair growth(Y/N)  Skin darkening (Y/N)  \
# 0                    7.0  ...                 0                     0
# 1                   11.0  ...                 0                     0
# 2                   10.0  ...                 0                     0
#
#    Hair loss(Y/N)  Pimples(Y/N)  Fast food (Y/N)  Reg.Exercise(Y/N)  \
# 0               0             0              1.0                  0
# ...

# %%
# Feature variance visualization

variances = df.drop('PCOS (Y/N)', axis=1).var()
plt.figure(figsize=(15, 6))
plt.bar(variances.index, variances.values)
plt.xlabel('Features')
plt.ylabel('Variance')
plt.title('Variance of Features (Excluding PCOS(Y/N))')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

cols_to_scale = df.drop('PCOS (Y/N)',axis=1).columns.to_list()

df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)       BMI  Blood Group  Pulse rate(bpm)   \
# 0           0   -0.634606 -1.236018     0.651284          1.073680
# 1           0    0.845230  0.146227     0.651284          0.169968
# 2           1    0.290291  0.244959    -1.523682         -0.281888
# 3           0    1.030210  1.331009    -0.436199         -0.281888
# 4           0   -1.189545 -1.038555    -1.523682         -0.281888
#
#    RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  Cycle length(days)  \
# 0          1.633608 -0.785169   -0.621534            0.039681
# 1          0.448119  0.623440   -0.621534            0.039681
# 2         -0.737370  0.738900   -0.621534            0.039681
# 3          0.448119  0.969819   -0.621534            0.039681
# 4         -0.737370 -1.339375   -0.621534            0.039681
#
#    Marraige Status (Yrs)  ...  hair growth(Y/N)  Skin darkening (Y/N)  \
# 0              -0.143700  ...          -0.61367             -0.665332
# ...

# %%
# re-viz
variances = df.drop('PCOS (Y/N)', axis=1).var()
plt.figure(figsize=(15, 6))
plt.bar(variances.index, variances.values)
plt.xlabel('Features')
plt.ylabel('Variance')
plt.title('Variance of Features (Excluding PCOS(Y/N))')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Engineering and EDA

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.model_selection import train_test_split
X = df.drop('PCOS (Y/N)',axis=1)
y = df['PCOS (Y/N)']
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=123)

# %%
# Recursive Feature Elimination
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

model = RandomForestClassifier(n_estimators=100, random_state=42)

rfe = RFE(estimator=model, n_features_to_select=11)
rfe.fit(X, y)

selected_features = X.columns[rfe.support_]
print("Selected Features:", list(selected_features))
# Out:
# Selected Features: [' Age (yrs)', 'BMI', 'Cycle(R/I)', 'LH(mIU/mL)', 'FSH/LH', 'TSH (mIU/L)', 'AMH(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)', 'Skin darkening (Y/N)', 'avg_num_folicol']

# %%
reduced_df = df[selected_features]
reduced_df.head()
# Out:
#     Age (yrs)       BMI  Cycle(R/I)  LH(mIU/mL)    FSH/LH  TSH (mIU/L)  \
# 0   -0.634606 -1.236018   -0.621534   -0.032219 -0.078253    -0.613338
# 1    0.845230  0.146227   -0.621534   -0.062129 -0.012120     0.047632
# 2    0.290291  0.244959   -0.621534   -0.064554 -0.009976    -0.117610
# 3    1.030210  1.331009   -0.621534   -0.047462 -0.057473     3.579026
# 4   -1.189545 -1.038555   -0.621534   -0.064323 -0.040981     0.156906
#
#    AMH(ng/mL)  Weight gain(Y/N)  hair growth(Y/N)  Skin darkening (Y/N)  \
# 0   -0.604743         -0.778037          -0.61367             -0.665332
# 1   -0.696716         -0.778037          -0.61367             -0.665332
# 2    0.171915         -0.778037          -0.61367             -0.665332
# 3   -0.749515         -0.778037          -0.61367             -0.665332
# 4   -0.572382         -0.778037          -0.61367             -0.665332
#
#    avg_num_folicol
# 0        -0.824385
# 1        -0.580873
# 2         1.854247
# 3        -1.067897
# ...

# %%
reduced_df['PCOS (Y/N)'] = df['PCOS (Y/N)']
df = reduced_df.copy()

print(reduced_df.shape)
print(df.shape)
# Out:
# (541, 12)
# (541, 12)
# <ipython-input-22-a56f269371c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['PCOS (Y/N)'] = df['PCOS (Y/N)']

# %%
df.head()
# Out:
#     Age (yrs)       BMI  Cycle(R/I)  LH(mIU/mL)    FSH/LH  TSH (mIU/L)  \
# 0   -0.634606 -1.236018   -0.621534   -0.032219 -0.078253    -0.613338
# 1    0.845230  0.146227   -0.621534   -0.062129 -0.012120     0.047632
# 2    0.290291  0.244959   -0.621534   -0.064554 -0.009976    -0.117610
# 3    1.030210  1.331009   -0.621534   -0.047462 -0.057473     3.579026
# 4   -1.189545 -1.038555   -0.621534   -0.064323 -0.040981     0.156906
#
#    AMH(ng/mL)  Weight gain(Y/N)  hair growth(Y/N)  Skin darkening (Y/N)  \
# 0   -0.604743         -0.778037          -0.61367             -0.665332
# 1   -0.696716         -0.778037          -0.61367             -0.665332
# 2    0.171915         -0.778037          -0.61367             -0.665332
# 3   -0.749515         -0.778037          -0.61367             -0.665332
# 4   -0.572382         -0.778037          -0.61367             -0.665332
#
#    avg_num_folicol  PCOS (Y/N)
# 0        -0.824385           0
# 1        -0.580873           0
# ...

# %% [markdown]
# ### Class Imbalance

# %%
df['PCOS (Y/N)'].value_counts()
# Out:
# PCOS (Y/N)
# 0    364
# 1    177
# Name: count, dtype: int64

# %%
# prompt: plot the class imbalance of PCOS (y/n)

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and 'PCOS (Y/N)' is your target column
pcos_counts = df['PCOS (Y/N)'].value_counts()

plt.figure(figsize=(8, 6))
sns.countplot(x='PCOS (Y/N)', data=df, color='orange')
plt.title('Class Imbalance: PCOS (Y/N)')
plt.xlabel('PCOS (Y/N)')
plt.ylabel('Count')

# Annotate the bars with counts
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                     textcoords='offset points')

plt.show()

# %%
from imblearn.over_sampling import SMOTE

X = df.drop('PCOS (Y/N)', axis=1)
y = df['PCOS (Y/N)']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

df_resampled = pd.DataFrame(X_resampled, columns=X.columns)
df_resampled['PCOS (Y/N)'] = y_resampled

print(df_resampled['PCOS (Y/N)'].value_counts())

# Now you can use df_resampled for your model training
# Out:
# PCOS (Y/N)
# 0    364
# 1    364
# Name: count, dtype: int64

# %%
# prompt: plot the class imbalance of PCOS (y/n)

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and 'PCOS (Y/N)' is your target column
pcos_counts = df_resampled['PCOS (Y/N)'].value_counts()

plt.figure(figsize=(8, 6))
sns.countplot(x='PCOS (Y/N)', data=df_resampled, color='orange')
plt.title('Class Imbalance Fixed: PCOS (Y/N)')
plt.xlabel('PCOS (Y/N)')
plt.ylabel('Count')

# Annotate the bars with counts
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                     textcoords='offset points')

plt.show()

# %% [markdown]
# ### Visualizations

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#features = df_resampled.drop('PCOS (Y/N)',axis=1).columns.to_list()  # Add more if needed

features = ['Weight gain(Y/N)', 'hair growth(Y/N)',
       'Skin darkening (Y/N)', 'avg_num_folicol']
# Pairplot with KDE plots
sns.pairplot(df_resampled, vars=features, hue='PCOS (Y/N)', diag_kind='kde')

# Apply KDE plots
plt.show()

# %%
df_resampled.columns
# Out:
# Index([' Age (yrs)', 'BMI', 'Cycle(R/I)', 'LH(mIU/mL)', 'FSH/LH',
#        'TSH (mIU/L)', 'AMH(ng/mL)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'avg_num_folicol', 'PCOS (Y/N)'],
#       dtype='object')

# %%
df_resampled.to_csv('PCOS Preprocessed.csv',index=False)

# %%
# prompt: create a correlational heatmap of df_resampled

# Calculate the correlation matrix
correlation_matrix = df_resampled.corr()

# Create the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
